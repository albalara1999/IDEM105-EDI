# %% [markdown]
# # Analyzing Your Transcript: Speech Turns and Dictionaries
#
# **NOTE:** Click [here](https://colab.research.google.com/github/senthilchandrasegaran/IDEM105-EDI/blob/main/03-reading-transcript-files.ipynb) to open the file in Colab.

# %% [markdown]
# ## Load Transcript Text
# Let's load your Transcript file from BrightSpace. Download your file and save it in a folder that allows you to load the file into this Notebook.
# If you are using Colab, you would need to first upload the file to Google Drive and then specify the link in the `read_excel` command below.
#
# Since this is an excel file, you will need to use a python library called *pandas* to read and process files as tables or "DataFrames".

# %%
import pandas as pd
# Use 'pd' as a shortcut for 'pandas' as it saves you the effort of typing 'pandas' every time.

# %% [markdown]
# It is convention to add a `_df` suffix to all variables that represent dataframes. So we load the transcript into a variable called `transcript_df`.

# %%
transcript_df = pd.read_excel('/content/Transccript.xlsx')
# Print a random sample of the dataframe, showing 5 rows.
transcript_df.sample(5)
# Out:
#      Unnamed: 0 timestamp speaker  \
# 147         147  00:19:27  Yiqing
# 414         414  00:59:16    Alba
# 499         499  01:10:13  Sophie
# 247         247  00:38:38  Sophie
# 492         492  01:09:50  Sophie
#
#                                              utterance
# 147  More smart technology in the park, for example...
# 414  But then it doesn't look impossible. My issue ...
# 499                                              Yeah.
# 247  And I finally asked her about safety. And she ...
# 492  Yeah, because also I feel like if you live nea...

# %% [markdown]
# This format is helpful, because just like we do in excel, we can count the rows, filter the table by a particular column value, and other manipulations of the table. We will explore a few of these approaches, but only in the context of what we are interested in, i.e., the analysis of the conversation recorded as the transcript.
#
# For instance, we can check how many speech turns (i.e., rows in the excel sheet) have been captured in the transcript.

# %%
print("Total number of speech turns : ", transcript_df.shape[0])
# Out:
# Total number of speech turns :  552

# %% [markdown]
# ## Analyzing participation
# Participation in a conversation is very subjective, and thus there is no one objective measure for it. However, we can explore a few aspects of participation. These could be the number of "speech turns", or the number of times a speaker spoke, or "utterance length": which could be how long (in time) a speaker spoke, or how long (in words) their utterances were.
#
# ### Number of Speech Turns
# Let's start simple. Who had the most speech turns?

# %%
# Let's first get a list of speakers attributed to each speech turn.
speakers = transcript_df['speaker'].to_list()

# We use the 'Counter' function from the 'collections' library to count the number of speech turns by speaker.
from collections import Counter
speaker_turn_counts = Counter(speakers)
print(speaker_turn_counts)
# Out:
# Counter({'Alba': 241, 'Sophie': 142, 'Yiqing': 87, 'Irene': 82})

# %% [markdown]
# ---
#
# #### NOTE:
# If you see any cases of misspelled speakers, or speaker names you think are wrong, it would be apparent in the above list.
#
# Go back to the excel file, fix the speakers if necessary, and run the above cells again until you get only the expected number of speakers.
#
# ---

# %% [markdown]
# #### Plotting the result
# We can also plot the speech turns for a nice graphical representation.
# First, let's create a new dataframe with the calculated information.

# %%
# Convert the 'counter' object that we have called `speaker_turn_counts' into a table, and then plot it.
turns_df = pd.DataFrame.from_dict(speaker_turn_counts, orient='index').reset_index()
turns_df
# Out:
#     index    0
# 0    Alba  241
# 1  Yiqing   87
# 2   Irene   82
# 3  Sophie  142

# %% [markdown]
# The column headers look awkward, so we can rename them.

# %%
turns_df = turns_df.rename(columns={"index": "Speaker", 0: "Turns"})
turns_df
# Out:
#   Speaker  Turns
# 0    Alba    241
# 1  Yiqing     87
# 2   Irene     82
# 3  Sophie    142

# %%
# Import the plotting library
import matplotlib.pyplot as plt
import seaborn as sns

scale = 0.6
figure_height = turns_df.shape[0] * scale
figure_width = figure_height * 3 * scale
plt.figure(figsize=(figure_width, figure_height))
g = sns.barplot(data=turns_df, x="Turns", y="Speaker", color='gray')

# %% [markdown]
# ## Tokenization & Word Count
# Last week, we tried tokenization of the entire transcript. This time, let's do it by speech turn.

# %%
import nltk
nltk.download('punkt_tab')  # comment this line after the first time you run this code.
from nltk import word_tokenize

# Make a list of all utterances in the transcript
utterances_list = transcript_df['utterance'].to_list()

# Iterate over this list and tokenize every utterance, saving the utterances as one list,
# and corresponding word counts as another list.
utterance_tokenized_list = []
utterance_word_counts = []
for utterance in utterances_list :
    tokens = word_tokenize(utterance)
    word_count = len(tokens)
    utterance_tokenized_list.append(tokens)
    utterance_word_counts.append(word_count)

# Add the new information to the existing dataframe as a new column.
transcript_df['utterance_tokens'] = utterance_tokenized_list
transcript_df['word_count'] = utterance_word_counts

# Let's take a look at our dataframe to see the new columns.
transcript_df.sample(3)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#      Unnamed: 0 timestamp speaker  \
# 23           23  00:01:32    Alba
# 359         359  00:53:30    Alba
# 317         317  00:48:49  Yiqing
#
#                                              utterance  \
# 23                 From people that go to these parks.
# 359  Yeah, yeah, yeah. That's for the presentation....
# 317                                         Yeah true.
#
#                                       utterance_tokens  word_count
# 23       [From, people, that, go, to, these, parks, .]           8
# 359  [Yeah, ,, yeah, ,, yeah, ., That, 's, for, the...          40
# 317                                    [Yeah, true, .]           3

# %%
# Let's use an eariler variable we established to get a non-repeating list of speakers.

speaker_names = turns_df['Speaker'].to_list()
speaker_word_counts = []

for speaker_name in speaker_names :
    speaker_df = transcript_df[transcript_df['speaker'] == speaker_name]
    speaker_wc = speaker_df['word_count'].sum()
    speaker_word_counts.append(speaker_wc)

if "Word Count" not in turns_df.columns :
    turns_df.insert(2, "Word Count", speaker_word_counts)
turns_df
# Out:
#   Speaker  Turns  Word Count
# 0    Alba    241        5845
# 1  Yiqing     87        1765
# 2   Irene     82        1517
# 3  Sophie    142        2650

# %% [markdown]
# Let's try that plot again, this time with word counts.

# %%
plt.figure(figsize=(figure_width, figure_height))
g = sns.barplot(data=turns_df, x="Word Count", y="Speaker", color='gray')

# %% [markdown]
# You can also try plotting the relationship between the turns and the word counts.
#
# Is the relationship linear? How else would you analyse turns vs words spoken?

# %%
# sns.scatterplot(data=turns_df, x="Word Count", y="Turns", color="gray")

from seaborn import axes_style
import seaborn.objects as so
so.Plot.config.theme.update(axes_style("white"))
p = so.Plot(data=turns_df, x="Word Count", y="Turns", text='Speaker').add(so.Dot(marker='o')).add(so.Text(halign='left')).show()

# %% [markdown]
# ## Dictionary Categories
# As you may have gathered from the reading assignments, dictionary categories in LIWC each have a list of words associated with that particular psycholinguistic process. For our example, let's look at the category `tentat` which indicates "tentativeness", often associated in design discussions with the proposal of an idea or a softening of judgement.
#
# Let's first load the words in this category via a file that I have created for you.

# %%
with open('/content/EDI-insight.txt', 'r') as fo:
    dictionary_terms_list = fo.readlines()

# We get rid of extraneous carriage return (\n) characters from the text
dictionary_terms_list = [w.strip('\n') for w in dictionary_terms_list]
print(dictionary_terms_list)
# Out:
# ['acceptable', 'admit*', 'afaik', 'afterthought*', 'analy*', 'answer*', 'answered', 'appreciat*', 'assum*', 'assumed', 'aware', 'aware', 'belier', 'believ*', 'believe', 'believed', 'believes', 'believing', 'brainstorm*', 'categoriz*', 'choice*', 'choose', 'chooses', 'choosin', 'choosing', 'chose', 'claimed', 'clarif*', 'closure', 'clue*', 'cognizant', 'cohere*', 'complex', 'complexity', 'complicate', 'complicated', 'complicates', 'complicating', 'complication*', 'compreh*', 'conceive*', 'concentrat*', 'concentrate', 'concentration', 'concept', 'concepts', 'conceptual', 'conclud*', 'concluded', 'conclus*', 'confess*', 'confessed', 'conjectur*', 'conjectured', 'conscious', 'conscious*', 'consider', 'consideration', 'considered', 'considering', 'considers', 'contemplat*', 'convinc*', 'cope', 'coped', 'copes', 'coping', 'curio*', 'dawned', 'dawning', 'decide', 'decided', 'decides', 'deciding', 'decipher*', 'decis*', 'deduc*', 'deductive', 'define', 'defined', 'defines', 'defines', 'defining', 'definition*', 'determine', 'determined', 'determines', 'determining', 'diagnos*', 'diagnostic*', 'discer*', 'discemed', 'disclo*', 'discover*', 'discovered', 'effect', 'elaborat', 'elaborate', 'enlighten*', 'evaluat*', 'evidence', 'evident', 'examine*', 'explain', 'explained', 'explaining', 'explains', 'explanat*', 'explor*', 'explored', 'feedback', 'feel', 'feel* better', 'feel* blue', 'feel* down', 'feel* guilt*', 'feel* low*', 'feel* pointless', 'feel* useless', 'feel* worthless', 'feelin', 'feeling', 'feelings', 'feels', 'felt', 'figur* * out', 'figur* out', 'figurative', 'figuratively', 'figured', 'figures', 'figuring', 'find', 'finding', 'findings', 'finds', 'flesh* out', 'found', 'genuine', 'guess*', 'guessed', 'guesses', 'guessing', 'hence', 'how', "how'd", "how'll", "how're", 'hows', "how've", 'howd', 'howll', 'howre', 'hows', 'howve', 'hypothes*', 'idea', 'ideas', 'identif*', 'imagin*', 'imagined', 'imagines', 'implie*', 'imply*', 'indeed', 'infer', 'inferen*', 'inferr*', 'inferred', 'infers', 'info', 'inform', 'information', 'informative*', 'informed', 'informing', 'informs', 'inquir*', 'insight*', 'inspect*', 'inspir*', 'interpret', 'intuit*', 'investig*', 'investigatory', 'ironic*', 'irrelevan*', 'justif*', 'key', 'knew', 'kno*', 'know', 'knowing', 'knowledg*', 'known*', 'knows', 'learn', 'learn* about', 'learned', 'learner*', 'learning', 'learns', 'learnt', 'lesson*', 'logic*', 'logical', 'matur*', 'mean', 'meaning*', 'meaninglul', 'means', 'meant', 'mediat*', 'methinks', 'mindb*', 'mindfuck*', 'misconception*', 'misinterpret*', 'misunder*', 'moreover', 'motiv*', 'musing', 'musings', 'not a good idea', 'not the case', 'notice', 'noticed', 'notices', 'noticing', 'obsess', 'obsessed', 'obsession', 'opinion*', 'organize', 'organized', 'organizes', 'organizing', 'perceiv*', 'percept*', 'perspective*', 'plan', 'planned', 'planning', 'plans', 'ponder', 'ponder*', 'pondered', 'pondering', 'prefer*', 'presum*', 'presumably', 'presume', 'presumed', 'prove', 'proved', 'proven', 'proves', 'proving', 'queried', 'queries', 'query', 'question', 'questioned', 'questioning', 'questions', 'rational', 'rational*', 'realisa*', 'realise*', 'realised', 'realising', 'realization*', 'realize', 'realized', 'realizes', 'realizing', 'reason*', 'reasonable', 'reasonably', 'reasoned', 'recall*', 'recalled', 'reckon*', 'recogni*', 'recognise', 'recognised', 'recognition', 'recognize', 'recognized', 'recollect*', 'reconcil*', 'reconsider*', 'reconsidered', 'reconstruct*', 'recreat*', 'reevaluat*', 'reflect*', 'relate*', 'related', 'relating', 'relation', 'relevan*', 'remember*', 'resolv*', 'resolved', 'resource', 'restructur*', 'rethink*', 'reveal', 'revealed', 'revealing', 'reveals', 'revelat*', 'review', 'revered', 'revisit*', 'ruminat*', 'seem', 'seemed', 'seeming', 'seeming*', 'seems', 'select', 'selected', 'selecting', 'selects', 'sense', 'sensed', 'senses', 'sensing', 'skeptic*', 'solution', 'solve', 'solved', 'solves', 'solving', 'speculat*', 'sus',  ...

# %% [markdown]
# ## Finding matches between dictionary and text
# The next step is to find how many terms from the text match the terms in the dictionary category, and to count every match. Note that I use the word "term" and not "word", since there are a number of multi-word terms in the dictionary, such as `kind of`.
#
# There are also some wildcards, indicated by `*`. A wildcard character indicates a general pattern. For instance, `option*` will return a match to `option`, `options`, `optional`, and `optionally`.
#
# Due to these wildcards and multi-word terms, we cannot simply use a token-by-token match to perform dictionary term matching. Instead, we will have to find patterns in the original text that match the patterns indicated in the dictionary entries. This includes single- and multi-word terms as well as terms that use wildcards. To achieve this, we will use a concept called [**regular expressions**](https://en.wikipedia.org/wiki/Regular_expression). In python, regular expressions are largely implemented using the ["`re`" library](https://docs.python.org/3/howto/regex.html#regex-howto).

# %%
import re

def count_matches(text, pattern):
    if pattern.startswith('*') :
        pattern = r"[A-Za-z]*" + pattern[1:]

    if pattern.endswith('*') :
        pattern = pattern[:-1] + r"[A-Za-z]*'"

    m = r"\b" + pattern + r"\b"
    matches = re.findall(pattern, text)
    return len(matches)

# %% [markdown]
# The above function that we have written, called `count_matches` looks for a given single- or multi-word pattern and returns the number of matches in a given text.
#
# See the example below for a demonstration of this code.

# %%
test = "or sort sort of like make a... yeah. like some sort of video."
num_matches = count_matches(test, 'sort of')
print("Number of matches:", num_matches)
# Out:
# Number of matches: 2

# %%
dict_term_counts = [0] * transcript_df.shape[0]

for ind, utterance in enumerate(utterances_list) :
    for dict_term in dictionary_terms_list :
        term_counts_in_utterance = count_matches(utterance.lower(), dict_term)
        dict_term_counts[ind] += term_counts_in_utterance

transcript_df["tentat_counts"] = dict_term_counts
transcript_df.sample(3)
# Out:
#      Unnamed: 0 timestamp speaker  \
# 160         160  00:20:50    Alba
# 422         422  01:00:02  Yiqing
# 43           43  00:03:29  Sophie
#
#                                              utterance  \
# 160  Was the description of the policeman enough or...
# 422                          Involve the local people.
# 43   Oh yeah. Visitor. Yeah. And we already had, li...
#
#                                       utterance_tokens  word_count  \
# 160  [Was, the, description, of, the, policeman, en...          30
# 422                   [Involve, the, local, people, .]           5
# 43   [Oh, yeah, ., Visitor, ., Yeah, ., And, we, al...          17
#
#      tentat_counts
# 160              2
# 422              0
# 43               0

# %%
def dict_term_score(dict_term_counts, word_count):
    dict_score = dict_term_counts/word_count
    return dict_score

transcript_df['liwc_tentat_score'] = transcript_df.apply(lambda x: dict_term_score(x['tentat_counts'], x['word_count']), axis=1)
transcript_df.sample(5)
# Out:
#      Unnamed: 0 timestamp speaker  \
# 283         283  00:45:46    Alba
# 205         205  00:30:01    Alba
# 103         103  00:12:36  Sophie
# 444         444  01:03:12   Irene
# 223         223  00:34:30  Sophie
#
#                                              utterance  \
# 283  Yeah. So I think as a summary overall, like ou...
# 205  Perception. Yeah. The perception of safety in ...
# 103                        Yeah. Exactly like I don't.
# 444  Yeah, maybe we can have one that it's differen...
# 223                             I can talk about mine.
#
#                                       utterance_tokens  word_count  \
# 283  [Yeah, ., So, I, think, as, a, summary, overal...          19
# 205  [Perception, ., Yeah, ., The, perception, of, ...          75
# 103            [Yeah, ., Exactly, like, I, do, n't, .]           8
# 444  [Yeah, ,, maybe, we, can, have, one, that, it,...          26
# 223                     [I, can, talk, about, mine, .]           6
#
#      tentat_counts  liwc_tentat_score
# 283              1           0.052632
# 205              1           0.013333
# 103              0           0.000000
# 444              2           0.076923
# 223              0           0.000000

# %%
tentat_df = transcript_df[transcript_df['liwc_tentat_score'] > 0]
print("Number of speech turns with a tentativeness score above zero:", tentat_df.shape[0])
# Out:
# Number of speech turns with a tentativeness score above zero: 214

# %%
dict_matches_for_speakers = []

for speaker_name in speaker_names :
    speaker_df = transcript_df[transcript_df['speaker'] == speaker_name]
    speech = ' '.join(speaker_df['utterance'].to_list()).lower()
    dict_matches = 0
    for dict_term in dictionary_terms_list :
        term_counts_in_utterance = count_matches(speech, dict_term)
        dict_matches += term_counts_in_utterance
    dict_matches_for_speakers.append(dict_matches)

if "Tentative Words" not in turns_df.columns :
    turns_df.insert(3, "Tentative Words", dict_matches_for_speakers)
if "Tentativeness Score" not in turns_df.columns :
    turns_df["Tentativeness Score"] = turns_df["Tentative Words"] / turns_df["Word Count"]
turns_df
# Out:
#   Speaker  Turns  Word Count  Tentative Words  Tentativeness Score
# 0    Alba    241        5845              215             0.036784
# 1  Yiqing     87        1765               83             0.047025
# 2   Irene     82        1517               69             0.045485
# 3  Sophie    142        2650               88             0.033208

# %% [markdown]
# ### Save your results!
# You can save your results as an excel file.

# %%
transcript_df.to_excel('./sample_data/sample_transcript_with_dict_score.xlsx')

# %% [markdown]
# ### Concordance Analysis
# Since dictionary-based scores are not sensitive to the contexts of word use, it might be a good idea to examine the contexts of word use.
#
# For this purpose, we use a **KWIC** or **K**ey**W**ord **I**n **C**ontext view that shows all occurrences of a word of interest in the context of its surrounding text.

# %%
from nltk.text import Text
transcript_text = ' '.join(transcript_df['utterance'].to_list()).lower()
tokens = word_tokenize(transcript_text)
textList = Text(tokens)

for term in dictionary_terms_list :
    print("Looking for occurrences of", term, "...")
    textList.concordance(term, width=85, lines=25)
# Out:
# Looking for occurrences of acceptable ...
# no matches
# Looking for occurrences of admit* ...
# no matches
# Looking for occurrences of afaik ...
# no matches
# Looking for occurrences of afterthought* ...
# no matches
# Looking for occurrences of analy* ...
# no matches
# Looking for occurrences of answer* ...
# no matches
# Looking for occurrences of answered ...
# Displaying 1 of 1 matches:
# e some of the question i asked and he answered . i feel like there 'll be more quest
# Looking for occurrences of appreciat* ...
# no matches
# Looking for occurrences of assum* ...
# no matches
# Looking for occurrences of assumed ...
# no matches
# Looking for occurrences of aware ...
# Displaying 6 of 6 matches:
# ah , yeah . and he 's probably the most aware of the public safety than the others ,
#  some of our stakeholders might only be aware of safety in specific places . specific
# s characters we did n't want them to be aware in a way of the increase of crime . let
# e did add in his description that he 's aware of it , but we did n't add any other co
# we did n't add anything about she being aware of this increase , just to see how she
# velling . so i think she would be extra aware , but she did n't always say anything a
# Looking for occurrences of aware ...
# Displaying 6 of 6 matches:
# ah , yeah . and he 's probably the most aware of the public safety than the others ,
#  some of our stakeholders might only be aware of safety in specific places . specific
# s characters we did n't want them to be aware in a way of the increase of crime . let
# e did add in his description that he 's aware of it , but we did n't add any other co
# we did n't add anything about she being aware of this increase , just to see how she
# velling . so i think she would be extra aware , but she did n't always say anything a
# Looking for occurrences of belier ...
# no matches
# Looking for occurrences of believ* ...
# no matches
# Looking for occurrences of believe ...
# no matches
# Looking for occurrences of believed ...
# Displaying 2 of 2 matches:
# so had experience in the past that he believed that in the past , the rotterdam park
# n that he said will be like . like he believed that more regular cleaning and also u
# Looking for occurrences of believes ...
# no matches
# Looking for occurrences of believing ...
# no matches
# Looking for occurrences of brainstorm* ...
# no matches
# Looking for occurrences of categoriz* ...
# no matches
# Looking for occurrences of choice* ...
# no matches
# Looking for occurrences of choose ...
# no matches
# Looking for occurrences of chooses ...
# no matches
# Looking for occurrences of choosin ...
# no matches
# Looking for occurrences of choosing ...
# Displaying 1 of 1 matches:
# like the community , can be a part of choosing the activities or something like that
# Looking for occurrences of chose ...
# Displaying 1 of 1 matches:
#  like that ai , at least the one that i chose to talk , is like constantly repeat the
# Looking for occurrences of claimed ...
# no matches
# Looking for occurrences of clarif* ...
# no matches
# Looking for occurrences of closure ...
# no matches
# Looking for occurrences of clue* ...
# no matches
# Looking for occurrences of cognizant ...
# no matches
# Looking for occurrences of cohere* ...
# no matches
# Looking for occurrences of complex ...
# no matches
# Looking for occurrences of complexity ...
# no matches
# Looking for occurrences of complicate ...
# no matches
# Looking for occurrences of complicated ...
# Displaying 1 of 1 matches:
# , but at least not using , like very complicated words . words because in a normal co
# Looking for occurrences of complicates ...
# no matches
# Looking for occurrences of complicating ...
# no matches
# Looking for occurrences of complication* ...
# no matches
# Looking for occurrences of compreh* ...
# no matches
# Looking for occurrences of conceive* ...
# no matches
# Looking for occurrences of concentrat* ...
# no matches
# Looking for occurrences of concentrate ...
# no matches
# Looking for occurrences of concentration ...
# no matches
# Looking for occurrences of concept ...
# Displaying 4 of 4 matches:
#  . the constraints . oh yeah . central concept and alternative ideas . or we can just
# i do n't think so . research , central concept , alternative ideas… a line of a propo
# combine them . yeah . and that 's our… concept . what is it ? design direction , and
# meant the design proposal as the final concept . ok. oh , i see . inside the design p
# Looking for occurrences of concepts ...
# Displaying 2 of 2 matches:
# e we can cluster them again to create concepts or something . it 's really nice . wh
#  and analyse the design session using concepts that you have been introduced during
# Looking for occurrences of conceptual ...
# no matches
# Looking for occurrences of conclud* ...
# no matches
# Looking for occurrences of concluded ...
# no matches
# Looking for occurrences of conclus* ...
# no matches
# Looking for occurrences of confess* ...
# no matches
# Looking for occurrences of confessed ...
# no matches
# Looking for occurrences of conjectur* ...
# no matches
# Looking for occurrences of conjectured ...
# no matches
# Looking for occurrences of conscious ...
# no matches
# Looking for occurrences of conscious* ...
# no matches
# Looking for occurrences of consider ...
# Displaying 1 of 1 matches:
# . and yeah , and she even said she 'd consider avoiding parts that are n't eco frien
# Looking for occurrences of consideration ...
# no matches
# Looking for occurrences of considered ...
# Displaying 3 of 3 matches:
# there are risks in the park . but he considered that he considered that it 's still
# the park . but he considered that he considered that it 's still a manageable area .
# h . for their… i do n't know . it 's considered a park . yeah . playgrounds . i see
# Looking for occurrences of considering ...
# no matches
# Looking for occurrences of considers ...
# no matches
# Looking for occurrences of contemplat* ...
# no matches
# Looking for occurrences of convinc* ...
# no matches
# Looking for occurrences of cope ...
# no matches
# Looking for occurrences of coped ...
# no matches
# Looking for occurrences of copes ...
# no matches
# Looking for occurrences of coping ...
# no matches
# Looking for occurrences of curio* ...
# no matches
# Looking for occurrences of dawned ...
# no matches
# Looking for occurrences of dawning ...
# no matches
# Looking for occurrences of decide ...
# Displaying 2 of 2 matches:
# ic weekend in a month of the year they decide to do a really big like food festival
# makes the events . so for example , we decide to , like , have , like maybe like a r
# Looking for occurrences of decided ...
# Displaying 2 of 2 matches:
#  be more inclusive . so that 's why we decided to add a disabled homeless person . an
# eless person . and that 's why we also decided to include a character that is like th
# Looking for occurrences of decides ...
# no matches
# Looking for occurrences of deciding ...
# no matches
# Looking for occurrences of decipher* ...
# no matches
# Looking for occurrences of decis* ...
# no matches
# Looking for occurrences of deduc* ...
# no matches
# Looking for occurrences of deductive ...
# no matches
# Looking for occurrences of define ...
# Displaying 3 of 3 matches:
# o we have to do , like , do we have to define now exactly , like , the… our defined
# eft to do is… ? how much do we want to define this proposal ? wait , so what… ? what
# h , i do n't know . i think we should… define it a little bit more… yeah . ok , so w
# Looking for occurrences of defined ...
# Displaying 1 of 1 matches:
# o define now exactly , like , the… our defined proposal , or do we have to , like , .
# Looking for occurrences of defines ...
# no matches
# Looking for occurrences of defines ...
# no matches
# Looking for occurrences of defining ...
# no matches
# Looking for occurrences of definition* ...
# no matches
# Looking for occurrences of determine ...
# no matches
# Looking for occurrences of determined ...
# no matches
# Looking for occurrences of determines ...
# no matches
# Looking for occurrences of determining ...
# no matches
# Looking for occurrences of diagnos* ...
# no matches
# Looking for occurrences of diagnostic* ...
# no matches
# Looking for occurrences of discer* ...
# no matches
# Looking for occurrences of discemed ...
# no matches
# Looking for occurrences of disclo* ...
# no matches
# Looking for occurrences of discover* ...
# no matches
# Looking for occurrences of discovered ...
# no matches
# Looking for occurrences of effect ...
# no matches
# Looking for occurrences of elaborat ...
# no matches
# Looking for occurrences of elaborate ...
# no matches
# Looking for occurrences of enlighten* ...
# no matches
# Looking for occurrences of evaluat* ...
# no matches
# Looking for occurrences of evidence ...
# Displaying 1 of 1 matches:
# do increase the camera , but like the evidence , the camera catching is like more li
# Looking for occurrences of evident ...
# no matches
# Looking for occurrences of examine* ...
# no matches
# Looking for occurrences of explain ...
# Displaying 2 of 2 matches:
# s ? we have the timeline , the… we can explain what 3 like the ideas from the cluster
# e the final proposal and to like find… explain what the final is about . yeah . shoul
# Looking for occurrences of explained ...
# no matches
# Looking for occurrences of explaining ...
# no matches
# Looking for occurrences of explains ...
# no matches
# Looking for occurrences of explanat* ...
# no matches
# Looking for occurrences of explor* ...
# no matches
# Looking for occurrences of explored ...
# no matches
# Looking for occurrences of feedback ...
# Displaying 1 of 1 matches:
#  's going on . so we need to get this feedback and . is that a combinator broad spec
# Looking for occurrences of feel ...
# Displaying 25 of 29 matches:
# ion of safety so we have to make people feel a little bit more safe , even though ma
# ey may be part of the reason why people feel unsafe . but we will know more once we
# ice function , maybe that would make us feel more like a real interview for a design
# ng irene ? that it 's more difficult to feel empathy , i think . yeah , yeah , yeah
# n you 're technically talking to . also feel like if we were to have prepared to int
# o n't have to be worried about how they feel about you or something . or like , yeah
#  less detailed . oh , go ahead . i also feel like would you interview a real homeles
# go and interview , then yeah . yeah , i feel like it 's going to be hard find one wh
# file and we tried to talk with them . i feel like that ai , at least the one that i
#  about when we doing this interview , i feel like i do n't know if they can really g
# me it is . again , yeah . yeah . did it feel like you were talking to ? a real perso
# . how was it ? yeah , it 's really like feel like talking to our real person . but l
# lking to our real person . but like , i feel like real policeman wo n't give that ma
# in the but for the conversation , it is feel like talking to a real person . mm . gr
# he question i asked and he answered . i feel like there 'll be more questions i can
# . maybe i can . i can go next because i feel like some of the insights that you got
# t was throwing me off . like it did n't feel like i was talking to a homeless person
# l , not increasing like , well , people feel less safe because of . because he obser
# was just thinking like , i wonder , i i feel like i very nonfrequently see homeless
# at is badly lit . yeah , true . but . i feel that 's an interesting insight . yeah .
# ple would go also in general . like , i feel like even the police talked about , lik
# e police immediately ? so she doesn ’ t feel really safer with that . yeah . and she
#  true . mm . for me , actually makes me feel less safe . because if i 'm seeing the
# bine back three of them or . ok. do you feel like going in one direction ? hmm . i f
# l like going in one direction ? hmm . i feel like lighting and more nice environment
# Looking for occurrences of feel* better ...
# no matches
# Looking for occurrences of feel* blue ...
# no matches
# Looking for occurrences of feel* down ...
# no matches
# Looking for occurrences of feel* guilt* ...
# no matches
# Looking for occurrences of feel* low* ...
# no matches
# Looking for occurrences of feel* pointless ...
# no matches
# Looking for occurrences of feel* useless ...
# no matches
# Looking for occurrences of feel* worthless ...
# no matches
# Looking for occurrences of feelin ...
# no matches
# Looking for occurrences of feeling ...
# Displaying 6 of 6 matches:
# ey also mentioned the community . like feeling of community , creating , like organis
# verall , like to keep like more safety feeling . i think they are also mentioned . ye
# hting situation and with the community feeling are two interesting paths . yeah . fro
# st i do n't know how the neighbourhood feeling , like how strong is the neighbourhood
# , like how strong is the neighbourhood feeling is here like i do n't know if people k
# ust like a community gathering kind of feeling like with some… food or providing like
# Looking for occurrences of feelings ...
# no matches
# Looking for occurrences of feels ...
# Displaying 2 of 2 matches:
# ing during the evenings . hmm . and she feels like that has led to , like , a reduced
#  really enjoyed going there and now she feels like it 's not her space anymore . mm .
# Looking for occurrences of felt ...
# Displaying 3 of 3 matches:
#  to go ahead . and we use ai because we felt like it was more natural , i think , ra
# acters , even with the pictures , so it felt more natural , i think we can even use
#  like to do there if they did , if they felt safe and they were like , go for a run
# Looking for occurrences of figur* * out ...
# no matches
# Looking for occurrences of figur* out ...
# no matches
# Looking for occurrences of figurative ...
# no matches
# Looking for occurrences of figuratively ...
# no matches
# Looking for occurrences of figured ...
# no matches
# Looking for occurrences of figures ...
# no matches
# Looking for occurrences of figuring ...
# no matches
# Looking for occurrences of find ...
# Displaying 2 of 2 matches:
# ah , i feel like it 's going to be hard find one who are willing to talk to about th
#  say that i also use chatgpt to help me find the most relevant insights from our con
# Looking for occurrences of finding ...
# no matches
# Looking for occurrences of findings ...
# no matches
# Looking for occurrences of finds ...
# no matches
# Looking for occurrences of flesh* out ...
# no matches
# Looking for occurrences of found ...
# no matches
# Looking for occurrences of genuine ...
# no matches
# Looking for occurrences of guess* ...
# no matches
# Looking for occurrences of guessed ...
# no matches
# Looking for occurrences of guesses ...
# no matches
# Looking for occurrences of guessing ...
# no matches
# Looking for occurrences of hence ...
# no matches
# Looking for occurrences of how ...
# Displaying 25 of 37 matches:
#  from the uk to get their insight , like how people like foreigners perceived safety
# erated pictures , maybe we can introduce how we talked , how we created these charact
# , maybe we can introduce how we talked , how we created these characters , what tools
# escription is more like , i think it was how the person would see him or herself , i
# ckground story and also like examples of how would they talk ? and so on . yeah . we
# ing aware of this increase , just to see how she would react once during the intervie
#  would react once during the interview , how she would react to this information . so
# like you do n't have to be worried about how they feel about you or something . or li
# r the through the interview . yeah . and how did it go ? did you like ? like did it g
# oh yeah , this person is definitely ai . how was it ? yeah , it 's really like feel l
#  i did . i had to be more specific about how he would uh speak to me like , not like
# ke , not like someone that does n't know how to speak at all , but at least not using
# ery like nothing too big . it was mostly how it was communicating that was throwing m
#  i wanted to have a quantitative idea of how . jay perceives safety in the park where
# ome of his things . pertenencies is that how you say it 's ? its property . and when
# hey tend to come to him and ask him like how he 's doing . and looking out for his we
# well lived , and maybe people are more . how do you say it… wary of like doing bad st
# n a different aspects she also mentioned how where she lived in her home country and
# em . yeah . yeah , because i do n't know how it works in here , in rotherham . but in
# r the amount of light in the area . mm . how specific does our proposal proposal have
# esentation . but i just do n't know like how specific do we have , like , do we know
# at , like the neighbours , i do n't know how far away the parks are 'cause . i think
# eek at least . yeah , just i do n't know how the neighbourhood feeling , like how str
# now how the neighbourhood feeling , like how strong is the neighbourhood feeling is h
# es and stuff . yeah . that makes sense . how many parks are in rotterdam . i tried to
# Looking for occurrences of how'd ...
# no matches
# Looking for occurrences of how'll ...
# no matches
# Looking for occurrences of how're ...
# no matches
# Looking for occurrences of hows ...
# no matches
# Looking for occurrences of how've ...
# no matches
# Looking for occurrences of howd ...
# no matches
# Looking for occurrences of howll ...
# no matches
# Looking for occurrences of howre ...
# no matches
# Looking for occurrences of hows ...
# no matches
# Looking for occurrences of howve ...
# no matches
# Looking for occurrences of hypothes* ...
# no matches
# Looking for occurrences of idea ...
# Displaying 8 of 8 matches:
#  situation . exactly because we have no idea about what 's going on . so we need to
# i ask , i wanted to have a quantitative idea of how . jay perceives safety in the pa
# ike movie night . oh yes , it 's a good idea . a scheduled… movie night is a nice li
# and grab something to eat . yeah . good idea . i think there ’ s 10 at least . 10 ?
# eah , i do n't . do we have , like , an idea of what we have to include in all of th
# he interviews , insights and then , the idea . so that 's two slides . yeah , maybe
#  if we… i think we already have like an idea of the proposal . so what we have left
# i think . but well , i think we have an idea ? i will… stop recording now . if we 'r
# Looking for occurrences of ideas ...
# Displaying 6 of 6 matches:
# make him have some kind of preconceived ideas so we want the ai to create its own per
# al . and do n't come up with like crazy ideas like be a realistic character . like do
#  yeah . central concept and alternative ideas . or we can just create an activity cal
# be we can have one that it 's different ideas . maybe for the clusters that we did an
# e we can do the… show the clustering of ideas . then how many slides do we have now w
# e , the… we can explain what 3 like the ideas from the cluster that we like more . th
# Looking for occurrences of identif* ...
# no matches
# Looking for occurrences of imagin* ...
# no matches
# Looking for occurrences of imagined ...
# no matches
# Looking for occurrences of imagines ...
# no matches
# Looking for occurrences of implie* ...
# no matches
# Looking for occurrences of imply* ...
# no matches
# Looking for occurrences of indeed ...
# no matches
# Looking for occurrences of infer ...
# no matches
# Looking for occurrences of inferen* ...
# no matches
# Looking for occurrences of inferr* ...
# no matches
# Looking for occurrences of inferred ...
# no matches
# Looking for occurrences of infers ...
# no matches
# Looking for occurrences of info ...
# no matches
# Looking for occurrences of inform ...
# no matches
# Looking for occurrences of information ...
# Displaying 11 of 11 matches:
# und for the like the more background information for each stakeholders try to get mor
# 's great that we add more background information to each stakeholders is because we a
# tually getting better if we add more information . so i think it can be more real and
# erview , how she would react to this information . so i think that 's important that
# we ? so we use chatgpt to create the information of all these characters . based on l
# ive us something you know more broad information or really ask like answer our questi
#  the police , i think . the safety . information . yeah . the question that 's like w
#  or five questions and we added more information and try to add more different angles
# yeah , he 'd actually give me a more information 'cause . i would . i like . i know n
#  n't know , like if it 's really new information for dutch people who live in rotterd
#  i think that 's it . we have enough information to have six slides , i think , and t
# Looking for occurrences of informative* ...
# no matches
# Looking for occurrences of informed ...
# no matches
# Looking for occurrences of informing ...
# no matches
# Looking for occurrences of informs ...
# no matches
# Looking for occurrences of inquir* ...
# no matches
# Looking for occurrences of insight* ...
# no matches
# Looking for occurrences of inspect* ...
# no matches
# Looking for occurrences of inspir* ...
# no matches
# Looking for occurrences of interpret ...
# no matches
# Looking for occurrences of intuit* ...
# no matches
# Looking for occurrences of investig* ...
# no matches
# Looking for occurrences of investigatory ...
# no matches
# Looking for occurrences of ironic* ...
# no matches
# Looking for occurrences of irrelevan* ...
# no matches
# Looking for occurrences of justif* ...
# no matches
# Looking for occurrences of key ...
# no matches
# Looking for occurrences of knew ...
# Displaying 1 of 1 matches:
#  people would come to the parks if they knew that . it was more focused on sustainab
# Looking for occurrences of kno* ...
# no matches
# Looking for occurrences of know ...
# Displaying 25 of 43 matches:
# parks . yeah , research a little bit to know more about the current situation . exac
# get a lot of tourist . so it 's good to know what they think . the homeless person d
# on why people feel unsafe . but we will know more once we talk with the stakeholder
# l . that for this case is more like . i know it 's not real , yeah . yeah . may be f
# g this interview , i feel like i do n't know if they can really give us something yo
# f they can really give us something you know more broad information or really ask li
# our questions . yeah , yeah . you never know . i ’ m more worried about the technolo
#  names for example like this . i do n't know if this is a real park . hopefully not
# a real park . hopefully not . i don ’ t know so like different parts have different
# ent that discourage the crime . and you know , just like encourage more positive vie
# formation 'cause . i would . i like . i know nothing about the rotterdam parks . so
# ite important to me at least . i do n't know , like if it 's really new information
# e like , not like someone that does n't know how to speak at all , but at least not
# i used the questions created . i do n't know who created the questions . i think it
# eeting with other children and i do n't know what exactly she said , but it was like
# one of them or something , but i do n't know . but i think . it 's what irene said .
# re nice environment could combine , you know . yeah , i feel like all of them can be
# system . yeah . yeah , because i do n't know how it works in here , in rotherham . b
# yeah and . if you have a space that you know that you 're going to use for special e
# or the presentation . but i just do n't know like how specific do we have , like , d
#  how specific do we have , like , do we know what we want to do like , you know ? an
# o we know what we want to do like , you know ? and they said , like , don ’ t waste
# rk protectors or ? like that , i do n't know . and like have a weekly event but happ
# re and like just rotate . mm . i do n't know . could be . and that way , like we hav
# o that , like the neighbours , i do n't know how far away the parks are 'cause . i t
# Looking for occurrences of knowing ...
# no matches
# Looking for occurrences of knowledg* ...
# no matches
# Looking for occurrences of known* ...
# no matches
# Looking for occurrences of knows ...
# Displaying 4 of 4 matches:
# ed going as often as before because she knows there are specific issues like thefts a
#  activities , but she does say that she knows a friend of a friend that was attacked
# ng also better surveillance because she knows there are , like , these cameras in the
#  the smaller parks , like if the police knows there 's an activity , then he can like
# Looking for occurrences of learn ...
# no matches
# Looking for occurrences of learn* about ...
# no matches
# Looking for occurrences of learned ...
# no matches
# Looking for occurrences of learner* ...
# no matches
# Looking for occurrences of learning ...
# no matches
# Looking for occurrences of learns ...
# no matches
# Looking for occurrences of learnt ...
# no matches
# Looking for occurrences of lesson* ...
# no matches
# Looking for occurrences of logic* ...
# no matches
# Looking for occurrences of logical ...
# no matches
# Looking for occurrences of matur* ...
# no matches
# Looking for occurrences of mean ...
# Displaying 6 of 6 matches:
# n na stop talking . but yeah , yeah , i mean it was . definitely less detailed . oh
# this ? yeah . exactly like i do n't . i mean , if i was alone , maybe not . if it 's
# look . let 's see . what do the colours mean ? that 's just from each person . so .
# just going to the park alone . yeah . i mean , they have to be crowd control enforce
# at a small park or something . like you mean we have… like a big movie night at a hu
#  their kids go run around at the park . mean . yeah , like . oh , maybe you can . we
# Looking for occurrences of meaning* ...
# no matches
# Looking for occurrences of meaninglul ...
# no matches
# Looking for occurrences of means ...
# Displaying 1 of 1 matches:
# lah blah blah . but it never explicitly means your sustain mentioned sustainability .
# Looking for occurrences of meant ...
# Displaying 1 of 1 matches:
# re something separate ? uh , i think we meant the design proposal as the final concep
# Looking for occurrences of mediat* ...
# no matches
# Looking for occurrences of methinks ...
# no matches
# Looking for occurrences of mindb* ...
# no matches
# Looking for occurrences of mindfuck* ...
# no matches
# Looking for occurrences of misconception* ...
# no matches
# Looking for occurrences of misinterpret* ...
# no matches
# Looking for occurrences of misunder* ...
# no matches
# Looking for occurrences of moreover ...
# no matches
# Looking for occurrences of motiv* ...
# no matches
# Looking for occurrences of musing ...
# no matches
# Looking for occurrences of musings ...
# no matches
# Looking for occurrences of not a good idea ...
# no matches
# Looking for occurrences of not the case ...
# no matches
# Looking for occurrences of notice ...
# Displaying 2 of 2 matches:
# ion of the policeman enough or did you notice something that you were like ? oh yeah
# is that i started talking to him . and notice that there were some speech traits or
# Looking for occurrences of noticed ...
# Displaying 1 of 1 matches:
# e like that was the first thing that i noticed and after that i maybe changed like sm
# Looking for occurrences of notices ...
# Displaying 1 of 1 matches:
#  the other challenge challenge that he notices is law enforcement enforcement and soc
# Looking for occurrences of noticing ...
# no matches
# Looking for occurrences of obsess ...
# no matches
# Looking for occurrences of obsessed ...
# no matches
# Looking for occurrences of obsession ...
# no matches
# Looking for occurrences of opinion* ...
# no matches
# Looking for occurrences of organize ...
# no matches
# Looking for occurrences of organized ...
# no matches
# Looking for occurrences of organizes ...
# no matches
# Looking for occurrences of organizing ...
# no matches
# Looking for occurrences of perceiv* ...
# no matches
# Looking for occurrences of percept* ...
# no matches
# Looking for occurrences of perspective* ...
# no matches
# Looking for occurrences of plan ...
# Displaying 7 of 7 matches:
# s . it does n't have to be like 1 urban plan or something . mm . just aspects to add
# ke a. but we could we could make like a plan for one of the parks that like each of
# an do kind of thing . or like a general plan that each of the parks can implement to
# ike in the size of the park . mhm . and plan events for smaller parks plan events fo
# mhm . and plan events for smaller parks plan events for medium sized parks and then
# so like i do n't think it 's so easy to plan a year ahead of events… of events . lik
# d of events… of events . like maybe you plan ahead like very ahead if you 're doing
# Looking for occurrences of planned ...
# no matches
# Looking for occurrences of planning ...
# no matches
# Looking for occurrences of plans ...
# no matches
# Looking for occurrences of ponder ...
# no matches
# Looking for occurrences of ponder* ...
# no matches
# Looking for occurrences of pondered ...
# no matches
# Looking for occurrences of pondering ...
# no matches
# Looking for occurrences of prefer* ...
# no matches
# Looking for occurrences of presum* ...
# no matches
# Looking for occurrences of presumably ...
# no matches
# Looking for occurrences of presume ...
# no matches
# Looking for occurrences of presumed ...
# no matches
# Looking for occurrences of prove ...
# no matches
# Looking for occurrences of proved ...
# no matches
# Looking for occurrences of proven ...
# no matches
# Looking for occurrences of proves ...
# no matches
# Looking for occurrences of proving ...
# no matches
# Looking for occurrences of queried ...
# no matches
# Looking for occurrences of queries ...
# no matches
# Looking for occurrences of query ...
# no matches
# Looking for occurrences of question ...
# Displaying 4 of 4 matches:
# the safeness of rotterdam park . good question . yeah . yeah . it 's not just one pa
# the safety . information . yeah . the question that 's like we created before is lik
# oh yeah . i asked because some of the question i asked and he answered . i feel like
#  i basically cover everything for the question . yeah . of the week . nice , nice ,
# Looking for occurrences of questioned ...
# no matches
# Looking for occurrences of questioning ...
# no matches
# Looking for occurrences of questions ...
# Displaying 14 of 14 matches:
#  , cared enough to make sure that the questions were like , sensitive or like , which
# rmation or really ask like answer our questions . yeah , yeah . you never know . i ’
# ike chatgpt only gave us really basic questions like four or five questions and we ad
# lly basic questions like four or five questions and we added more information and try
# d more different angles for different questions . so from this police who worked , i
#  . great . mm hmm . did you ask other questions than the ones that ? no . oh yeah . i
# wered . i feel like there 'll be more questions i can ask and then i 'll but like i b
# see i one of the i i we created these questions . well , i used the questions created
# d these questions . well , i used the questions created . i do n't know who created t
# eated . i do n't know who created the questions . i think it was you , sophie and yiq
# , sophie and yiqing . you created the questions for the homeless person i use , the o
# ould add more to it . i i asked extra questions that are not in the list , but they a
# he list , but they are just follow up questions from the ones that are already there.
# there.and like one of those follow up questions that i ask , i wanted to have a quant
# Looking for occurrences of rational ...
# no matches
# Looking for occurrences of rational* ...
# no matches
# Looking for occurrences of realisa* ...
# no matches
# Looking for occurrences of realise* ...
# no matches
# Looking for occurrences of realised ...
# no matches
# Looking for occurrences of realising ...
# no matches
# Looking for occurrences of realization* ...
# no matches
# Looking for occurrences of realize ...
# no matches
# Looking for occurrences of realized ...
# no matches
# Looking for occurrences of realizes ...
# no matches
# Looking for occurrences of realizing ...
# no matches
# Looking for occurrences of reason* ...
# no matches
# Looking for occurrences of reasonable ...
# no matches
# Looking for occurrences of reasonably ...
# no matches
# Looking for occurrences of reasoned ...
# no matches
# Looking for occurrences of recall* ...
# no matches
# Looking for occurrences of recalled ...
# no matches
# Looking for occurrences of reckon* ...
# no matches
# Looking for occurrences of recogni* ...
# no matches
# Looking for occurrences of recognise ...
# no matches
# Looking for occurrences of recognised ...
# no matches
# Looking for occurrences of recognition ...
# no matches
# Looking for occurrences of recognize ...
# no matches
# Looking for occurrences of recognized ...
# no matches
# Looking for occurrences of recollect* ...
# no matches
# Looking for occurrences of reconcil* ...
# no matches
# Looking for occurrences of reconsider* ...
# no matches
# Looking for occurrences of reconsidered ...
# no matches
# Looking for occurrences of reconstruct* ...
# no matches
# Looking for occurrences of recreat* ...
# no matches
# Looking for occurrences of reevaluat* ...
# no matches
# Looking for occurrences of reflect* ...
# no matches
# Looking for occurrences of relate* ...
# no matches
# Looking for occurrences of related ...
# Displaying 5 of 5 matches:
# onal violence that can relate to knife related incidents . like , especially theft .
# e park . some of them are not directly related to safety and like because of crime re
# ed to safety and like because of crime related activities . and the other challenge c
# o i do think that like doing something related to the lighting situation and with the
# e of them , the lack of light is still related . where is the lack of lights section
# Looking for occurrences of relating ...
# no matches
# Looking for occurrences of relation ...
# no matches
# Looking for occurrences of relevan* ...
# no matches
# Looking for occurrences of remember* ...
# no matches
# Looking for occurrences of resolv* ...
# no matches
# Looking for occurrences of resolved ...
# no matches
# Looking for occurrences of resource ...
# no matches
# Looking for occurrences of restructur* ...
# no matches
# Looking for occurrences of rethink* ...
# no matches
# Looking for occurrences of reveal ...
# no matches
# Looking for occurrences of revealed ...
# no matches
# Looking for occurrences of revealing ...
# no matches
# Looking for occurrences of reveals ...
# no matches
# Looking for occurrences of revelat* ...
# no matches
# Looking for occurrences of review ...
# no matches
# Looking for occurrences of revered ...
# no matches
# Looking for occurrences of revisit* ...
# no matches
# Looking for occurrences of ruminat* ...
# no matches
# Looking for occurrences of seem ...
# Displaying 1 of 1 matches:
# posal proposal have to be ? it does n't seem like they cared very much . as much as
# Looking for occurrences of seemed ...
# Displaying 1 of 1 matches:
# cross this sketchy group of people who seemed a little suspicious . but like , it wa
# Looking for occurrences of seeming ...
# no matches
# Looking for occurrences of seeming* ...
# no matches
# Looking for occurrences of seems ...
# no matches
# Looking for occurrences of select ...
# no matches
# Looking for occurrences of selected ...
# no matches
# Looking for occurrences of selecting ...
# no matches
# Looking for occurrences of selects ...
# no matches
# Looking for occurrences of sense ...
# Displaying 7 of 7 matches:
# ly what he said , yeah . it makes quite sense . quite a lot of sense . yeah , yeah ,
# . it makes quite sense . quite a lot of sense . yeah , yeah , these are the insights
#  or with the children 's . yeah , makes sense . yeah . yeah . so basically she mentio
# then i think it 's more , it makes more sense to have like weekly events than having
# ctivities and stuff . yeah . that makes sense . how many parks are in rotterdam . i t
# nths to organise it , so maybe it makes sense to have , like , a monthly calendar . y
# ds and then divide them by . that makes sense , yeah . nice . but then it 's like… se
# Looking for occurrences of sensed ...
# no matches
# Looking for occurrences of senses ...
# no matches
# Looking for occurrences of sensing ...
# no matches
# Looking for occurrences of skeptic* ...
# no matches
# Looking for occurrences of solution ...
# Displaying 2 of 2 matches:
# er home country and she had like this solution of going to the parks to have , like
# dding more safety measures is not the solution . no . it could be one of them or som
# Looking for occurrences of solve ...
# no matches
# Looking for occurrences of solved ...
# no matches
# Looking for occurrences of solves ...
# no matches
# Looking for occurrences of solving ...
# no matches
# Looking for occurrences of speculat* ...
# no matches
# Looking for occurrences of sus ...
# no matches
# Looking for occurrences of suspect* ...
# no matches
# Looking for occurrences of suspected ...
# no matches
# Looking for occurrences of suspicious ...
# Displaying 1 of 1 matches:
#  group of people who seemed a little suspicious . but like , it was one time . and i
# Looking for occurrences of suspicious* ...
# no matches
# Looking for occurrences of suspiciously ...
# no matches
# Looking for occurrences of tbh ...
# no matches
# Looking for occurrences of theor* ...
# no matches
# Looking for occurrences of therefor* ...
# no matches
# Looking for occurrences of think ...
# Displaying 25 of 83 matches:
# ah , that 's basically the main thing i think . yeah . so to do that , we want to get
# e have listed a lot of stakeholders . i think around 20s , right ? yeah , we got a lo
# lders , but maybe it 's worth it to … i think originally we had… because right now we
#  . but why ? why did we change this ? i think because the , umm , the coworker of our
# e routed in historical exclusion . so i think it ’ s nice that we are more inclusive
# omething that they also pointed out . i think our coworker , he pointed out that we n
#  try to get more inclusive opinions , i think . exactly also . and so we had , like t
# urist . so it 's good to know what they think . the homeless person directly lives in
# lection . yeah , sounds good . yeah , i think the more normal stakeholder that we hav
# e overall situation . yeah . and also i think it 's great that we add more background
# etter if we add more information . so i think it can be more real and practical when
# nterview so . exactly . i also honestly think it helped me to have the picture of the
# we did . yeah . because now that when i think about it , i think the whole time about
# ause now that when i think about it , i think the whole time about this version of ch
# se we felt like it was more natural , i think , rather than having to train chatgpt ,
#  pictures , so it felt more natural , i think we can even use the voice function , ma
#  , and the description is more like , i think it was how the person would see him or
# the person would see him or herself , i think . and then the definition is more like
# y talk ? and so on . yeah . we also , i think it 's important that we mentioned here
#  would react to this information . so i think that 's important that we mentioned . a
# t 's more difficult to feel empathy , i think . yeah , yeah , yeah . and also be care
#  what we did to create the profiles . i think we did n't say that we used chatgpt ? o
# us a lot longer just because . i do n't think we , like , cared enough to make sure t
# r life . yeah , that 's true . yeah , i think you adapt to more oriented towards them
# ld have been in person , but . yeah . i think it hopefully it helped to put do n't ag
# Looking for occurrences of think* back ...
# no matches
# Looking for occurrences of thinker* ...
# no matches
# Looking for occurrences of thinking ...
# Displaying 2 of 2 matches:
# y 's conversation . nice . i was just thinking like , i wonder , i i feel like i ver
#  for security purposes . yeah . i was thinking of something and now i forgot . but w
# Looking for occurrences of thinks ...
# Displaying 2 of 2 matches:
# s are eco friendly parks . and now she thinks that more young people would come to t
#  were community based . umm , she even thinks other people won ’ t come . mm . and y
# Looking for occurrences of thought ...
# Displaying 4 of 4 matches:
# at kind of perspective we were missing thought about while we were talking to them .
# ? did you like ? like did it go as you thought it would ? yeah , he 'd actually give
# ah . and for us as designers , he also thought it would be important that we design f
# least compared to the us . mm . i also thought about it . yeah . that 's true . well
# Looking for occurrences of thought back ...
# no matches
# Looking for occurrences of thoughtful ...
# no matches
# Looking for occurrences of thoughtful* ...
# no matches
# Looking for occurrences of thoughtfully ...
# no matches
# Looking for occurrences of thoughts ...
# no matches
# Looking for occurrences of thus* ...
# no matches
# Looking for occurrences of tolerat* ...
# no matches
# Looking for occurrences of tolerate ...
# no matches
# Looking for occurrences of trickier ...
# no matches
# Looking for occurrences of trickiest ...
# no matches
# Looking for occurrences of tricky ...
# no matches
# Looking for occurrences of troubleshoot ...
# no matches
# Looking for occurrences of unaware ...
# no matches
# Looking for occurrences of unaware* ...
# no matches
# Looking for occurrences of understand ...
# Displaying 1 of 1 matches:
# ive yeah . well , yeah , i think you understand me . if i say you representative lik
# Looking for occurrences of understand* you ...
# no matches
# Looking for occurrences of understandab* ...
# no matches
# Looking for occurrences of understanding* ...
# no matches
# Looking for occurrences of understands ...
# no matches
# Looking for occurrences of understood ...
# no matches
# Looking for occurrences of understood you ...
# no matches
# Looking for occurrences of unrelat* ...
# no matches
# Looking for occurrences of wisdom ...
# no matches
# Looking for occurrences of wonder ...
# Displaying 2 of 2 matches:
#  . nice . i was just thinking like , i wonder , i i feel like i very nonfrequently s
# r if you see more , more cameras , you wonder like , what are going on here that the
# Looking for occurrences of wondered ...
# no matches
# Looking for occurrences of wondering ...
# no matches
# Looking for occurrences of wonders ...
# no matches
# Looking for occurrences of *'nt a good idea ...
# no matches
# Looking for occurrences of *'nt the case ...
# no matches
# Looking for occurrences of *nt a good idea ...
# no matches
# Looking for occurrences of *nt the case ...
# no matches

# %%
# In case you are looking for a specific term:
specific_term = "design"
textList.concordance(specific_term, width=85, lines=25)
# Out:
# Displaying 21 of 21 matches:
#  feel more like a real interview for a design project because we 're used to just ch
# l . yeah . yeah , it may be for a real design project . it would be nice to do this
#  thought it would be important that we design from a very , from an empathetic and i
# gories . yeah . do we need to create 1 design or ? i think he said it could be diffe
# lternative ideas… a line of a proposed design . oh , but i 'm reading now like the…
#  now like the… task like page 3 in the design brief , and it says : point 3 is like
# hold and record a one to two hour team design session . drawing on the insides of th
# , point 4 , transcribe and analyse the design session using concepts that you have b
# ading . and then , five , present your design proposal like it… what do we have to d
# nd that 's our… concept . what is it ? design direction , and then the final design
#  design direction , and then the final design . yeah . i do n't know how many slides
# m the cluster that we like more . then design proposals and design and the final des
#  like more . then design proposals and design and the final design , and then we wou
# ign proposals and design and the final design , and then we would already have 6. de
# gn , and then we would already have 6. design proposal and final design , what 's th
# eady have 6. design proposal and final design , what 's the difference ? so for in t
# ou can have 3 or 4. oh , ok. the final design . it can be . yeah . we mix these and
# t . yeah . should we work on the final design proposal together for the recording an
# g separate ? uh , i think we meant the design proposal as the final concept . ok. oh
#  concept . ok. oh , i see . inside the design proposal , yeah . ok , ok. yeah , i do
# oposal is that later like . during the design we would analyse the closest parks to
